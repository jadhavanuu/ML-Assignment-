# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("C:/Users/Anita Jadhav/Desktop/jupyter programs/Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.shape
# Out:
# (30, 2)

# %%
#YearsExperience =[1.1,1.3,2.0]
#Salary = [39343.0,46205.0,43525.0]
type1 =data['YearsExperience']
type2= data['Salary']
#plt.scatter(YearsExperience,Salary)
plt.scatter(data['YearsExperience'],data['Salary'])
plt.title('salary vs year of experience')
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.show()

# %%
X = data.iloc[:, :1]
Y= data.iloc [:,1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)

# %%
# Prediction on training set
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Test Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
print(f'Coefficient: {regressor.coef_}')
print(f'Intercept: {regressor.intercept_}')
# Out:
# Coefficient: [[9312.57512673]]
# Intercept: [26780.09915063]

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# mse = mean_squared_error(y_test, y_pred_test)
# print("Mean Squared Error (Test Set):", mse)

# %%
mse = mean_squared_error(y_test, y_pred_test)
print("Mean Squared Error (Test Set):", mse)
# Out:
# Mean Squared Error (Test Set): 12823412.298126549

# %%
from sklearn.metrics import mean_absolute_error
mse = mean_squared_error(y_test, y_pred_test)
rmse = np.sqrt(mse)

print("Correct RMSE:", rmse)
# Out:
# Correct RMSE: 3580.979237321343

# %%
mae = mean_absolute_error(y_test, y_pred_test)
print("Mean Absolute Error (Test Set):", mae)
# Out:
# Mean Absolute Error (Test Set): 2446.1723690465055

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred_test)
print("R² Score (Test Set):", r2)
# Out:
# R² Score (Test Set): 0.988169515729126

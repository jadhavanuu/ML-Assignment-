# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Anita Jadhav/Desktop/jupyter programs/data.csv")

# %%
# understanding the data

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
data.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
data.shape
# Out:
# (7253, 14)

# %%
data.describe()
# Out:
#              S.No.         Year  Kilometers_Driven        Seats        Price
# count  7253.000000  7253.000000       7.253000e+03  7200.000000  6019.000000
# mean   3626.000000  2013.365366       5.869906e+04     5.279722     9.479468
# std    2093.905084     3.254421       8.442772e+04     0.811660    11.187917
# min       0.000000  1996.000000       1.710000e+02     0.000000     0.440000
# 25%    1813.000000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3626.000000  2014.000000       5.341600e+04     5.000000     5.640000
# 75%    5439.000000  2016.000000       7.300000e+04     5.000000     9.950000
# max    7252.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
data['Name'].unique()
# Out:
# array(['Maruti Wagon R LXI CNG', 'Hyundai Creta 1.6 CRDi SX Option',
#        'Honda Jazz V', ..., 'Ford EcoSport 1.5 Petrol Ambiente',
#        'Jeep Compass 1.4 Sport', 'Hyundai Elite i20 Magna Plus'],
#       shape=(2041,), dtype=object)

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
Name= data.drop(['Location','S.No.',],axis=1) #drop column(droping the redundant data which is not nnecessarily)

# %%
Name.head()
# Out:
#                                Name  Year  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R LXI CNG  2010              72000       CNG
# 1  Hyundai Creta 1.6 CRDi SX Option  2015              41000    Diesel
# 2                      Honda Jazz V  2011              46000    Petrol
# 3                 Maruti Ertiga VDI  2012              87000    Diesel
# 4   Audi A4 New 2.0 TDI Multitronic  2013              40670    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0        NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0        NaN
# 2       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0  8.61 Lakh
# 3       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0        NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0        NaN
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
print(data.columns)
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
from datetime import date
date.today().year
data['Car_Age']=date.today().year-data['Year']
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price  Car_Age
# 0  58.16 bhp    5.0        NaN   1.75       15
# ...

# %%
data['Brand'] = data.Name.str.split().str.get(0)

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price  Car_Age    Brand
# 0  58.16 bhp    5.0        NaN   1.75       15   Maruti
# ...

# %%
data['Model'] = data.Name.str.split().str.get(1) + data.Name.str.split().str.get(2)

# %%
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Car_Age', 'Brand', 'Model'],
#       dtype='object')

# %%
data[['Name', 'Brand', 'Model']]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                  Model
# 0               WagonR
# 1             Creta1.6
# 2                JazzV
# ...

# %%
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Car_Age', 'Brand', 'Model'],
#       dtype='object')

# %%
print(data.Brand.unique())
print(data.Brand.nunique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']
# 33

# %%
searchfor = ['Maruti' ,'ISUZU','Mini','Land']
data[data.Brand.str.contains('|'.join(searchfor))].head(5)
# Out:
#     S.No.                              Name Location  Year  Kilometers_Driven  \
# 0       0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 3       3                 Maruti Ertiga VDI  Chennai  2012              87000
# 10     10                  Maruti Ciaz Zeta    Kochi  2018              25692
# 12     12             Maruti Swift VDI BSIV   Jaipur  2015              64424
# 13     13  Land Rover Range Rover 2.2L Pure    Delhi  2014              72000
#
#    Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 0        CNG       Manual      First  26.6 km/kg   998 CC   58.16 bhp    5.0
# 3     Diesel       Manual      First  20.77 kmpl  1248 CC   88.76 bhp    7.0
# 10    Petrol       Manual      First  21.56 kmpl  1462 CC  103.25 bhp    5.0
# 12    Diesel       Manual      First   25.2 kmpl  1248 CC      74 bhp    5.0
# 13    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
#
# ...

# %%
data["Brand"].replace({"ISUZU": "Isuzu", "Mini": "Mini Cooper","Land":"Land Rover"}, inplace=True)

# %%
data['Brand'].value_counts()
# Out:
# Brand
# Maruti           1444
# Hyundai          1340
# Honda             743
# Toyota            507
# Mercedes-Benz     380
# Volkswagen        374
# Ford              351
# Mahindra          331
# BMW               312
# Audi              285
# Tata              228
# Skoda             202
# Renault           170
# Chevrolet         151
# Nissan            117
# Land Rover         67
# Jaguar             48
# Fiat               38
# Mitsubishi         36
# Mini Cooper        31
# Volvo              28
# Porsche            19
# Jeep               19
# Datsun             17
# Isuzu               5
# Force               3
# Bentley             2
# Ambassador          1
# Smart               1
# Lamborghini         1
# Hindustan           1
# OpelCorsa           1
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price  Car_Age    Brand      Model
# 0  58.16 bhp    5.0        NaN   1.75       15   Maruti     WagonR
# ...

# %%
data.describe().T
# Out:
#                     count          mean           std      min      25%  \
# S.No.              7253.0   3626.000000   2093.905084     0.00   1813.0
# Year               7253.0   2013.365366      3.254421  1996.00   2011.0
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.0
# Seats              7200.0      5.279722      0.811660     0.00      5.0
# Price              6019.0      9.479468     11.187917     0.44      3.5
# Car_Age            7253.0     11.634634      3.254421     6.00      9.0
#
#                         50%       75%        max
# S.No.               3626.00   5439.00     7252.0
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  53416.00  73000.00  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.64      9.95      160.0
# Car_Age               11.00     14.00       29.0

# %%
# Step 9: EDA Univariate Analysis

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Value:")
print(cat_cols)
print("Numerical Value:")
print(num_cols)
# Out:
# Categorical Value:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'New_Price'],
#       dtype='object')
# Numerical Value:
# ['S.No.', 'Year', 'Kilometers_Driven', 'Seats', 'Price']

# %%
data['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel      3852
# Petrol      3325
# CNG           62
# LPG           12
# Electric       2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Data
fuel_types = ['Diesel', 'Petrol', 'CNG', 'LPG']
counts = [30, 25, 12, 20]

# Plotting
plt.bar(fuel_types, counts, color='darkblue')

# Labels
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.title('Fuel Type Distribution')
# Out:
# Text(0.5, 1.0, 'Fuel Type Distribution')

# %%
import matplotlib.pyplot as plt

# Data
fuel_types = ['Diesel', 'Petrol', 'CNG']
counts = [30, 15, 52]

# Pie chart
plt.pie(counts, labels=fuel_types, autopct='%1.1f%%')

# Title
plt.title('Fuel Type Distribution')
# Out:
# Text(0.5, 1.0, 'Fuel Type Distribution')

# %%
# bivariate analysis

# %%
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Car_Age', 'Brand', 'Model'],
#       dtype='object')

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Value:")
print(cat_cols)
print("Numerical Value:")
print(num_cols)
# Out:
# Categorical Value:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'New_Price'],
#       dtype='object')
# Numerical Value:
# ['S.No.', 'Year', 'Kilometers_Driven', 'Seats', 'Price']

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
# scatter plot graph
import matplotlib.pyplot as plt
Price = [30, 10, 50, 40, 15, 60, 17]
Year = [2010, 2015, 2013, 2011, 2012, 2014, 2016]  

plt.scatter(Price, Year)
plt.xlabel('Price')
plt.ylabel('Year')
plt.title('Price vs Year (Sample)')
plt.show()

# %%
# Categorical-Categorical Type

# %%
small_data = data[['Fuel_Type', 'Transmission']].head(10)  #numerical-numerical type
small_data
# Out:
#   Fuel_Type Transmission
# 0       CNG       Manual
# 1    Diesel       Manual
# 2    Petrol       Manual
# 3    Diesel       Manual
# 4    Diesel    Automatic
# 5       LPG       Manual
# 6    Diesel       Manual
# 7    Diesel    Automatic
# 8    Diesel       Manual
# 9    Diesel       Manual

# %%
import pandas as pd
cat_cat = pd.crosstab(data['Fuel_Type'], data['Transmission'])
cat_cat
# Out:
# Transmission  Automatic  Manual
# Fuel_Type
# CNG                   0      62
# Diesel             1317    2535
# Electric              2       0
# LPG                   0      12
# Petrol              730    2595

# %%
cat_cat.plot(kind='bar') 
plt.title('Fuel Type vs Transmission')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.legend(title='Transmission')
plt.show()

# %%
#categorical and numerical

# %%
small_data = data[['Fuel_Type', 'Price']].head(5)
small_data
# Out:
#   Fuel_Type  Price
# 0       CNG   1.75
# 1    Diesel  12.50
# 2    Petrol   4.50
# 3    Diesel   6.00
# 4    Diesel  17.74

# %%
type = data['Fuel_Type']
type2 =data['Price']
plt.bar(type, type2)
plt.xlabel('Price')
plt.ylabel('Fuel_Type')
plt.title('Price vs Fuel_Type')
plt.show()
